# %% [markdown]
# <a href="https://colab.research.google.com/github/custom-hyper/google-trends/blob/master/google_trends_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motivation
#
# This workbook scales the tracking of various Google Trends searches that I am personally interested in.
#
#
#
# ---

# %% [markdown]
# # Setup

# %%
#@title
#@title Install Dependencies
# !pip install pytrends
# !pwd

import seaborn as sns
# Out:
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=d9620be9448670a6aca984dc05e4c520d98d2677eed44927583a1d93990277ff
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# ...
# /content

# %% [markdown]
# #Results
#  ---

# %%
#@title Crypto + Meme 

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto','Dogecoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Dogecoin', 'y4', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('giants.csv', encoding='utf-8')
# Out:
#             Bitcoin  Ethereum  Crypto  Dogecoin  isPartial
# date
# 2022-02-20       30         6      11         1      False
# 2022-02-27       27         5      10         1      False
# 2022-03-06       24         4      10         1      False
# 2022-03-13       20         4       9         1      False
# 2022-03-20       20         5       9         1      False
# 2022-03-27       22         6      11         1      False
# 2022-04-03       19         5       9         2      False
# 2022-04-10       20         4       9         1      False
# 2022-04-17       17         4       8         1      False
# 2022-04-24       15         3       7         1       True

# %%
#@title Bitcoin versus Ethereum

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Bitcoin', 'y1', data=df,linestyle='-', linewidth=1, marker='o', ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, color='blue',linestyle='-', linewidth=1, marker='o', ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()

plt.grid()
# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('giants.csv', encoding='utf-8')
# Out:
#             Bitcoin  Ethereum  isPartial
# date
# 2022-02-20       30         6      False
# 2022-02-27       27         5      False
# 2022-03-06       24         4      False
# 2022-03-13       20         4      False
# 2022-03-20       20         5      False
# 2022-03-27       22         6      False
# 2022-04-03       19         5      False
# 2022-04-10       20         4      False
# 2022-04-17       17         4      False
# 2022-04-24       15         3       True

# %%
#@title Layer 1
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polkadot', 'Cardano', 'Ethereum', 'Solana'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Polkadot', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Cardano', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Solana', 'y4', data=df, marker='o', color='orange',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Stellar', 'y5', data=df, marker='o', color='red', linewidth=2)
plt.legend()
plt.xticks(rotation=45)
# title
plt.title('Google Trends', loc='center',pad=10)

#sns.lineplot(data=df, x="date", y="score")
plt.show()

interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Polkadot  Cardano  Ethereum  Solana  isPartial
# date
# 2022-02-20         1        6        29       5      False
# 2022-02-27         1        5        26       5      False
# 2022-03-06         1        4        23       5      False
# 2022-03-13         1        4        21       5      False
# 2022-03-20         1        7        25       5      False
# 2022-03-27         1        6        28       7      False
# 2022-04-03         1        5        23       6      False
# 2022-04-10         1        4        21       5      False
# 2022-04-17         1        4        19       5      False
# 2022-04-24         1        4        14       5       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['AAVE'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'AAVE', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             AAVE  isPartial
# date
# 2022-02-20    32      False
# 2022-02-27    29      False
# 2022-03-06    31      False
# 2022-03-13    35      False
# 2022-03-20    42      False
# 2022-03-27    47      False
# 2022-04-03    37      False
# 2022-04-10    39      False
# 2022-04-17    33      False
# 2022-04-24    30       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Ukraine'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Ukraine', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Ukraine  isPartial
# date
# 2022-02-20      100      False
# 2022-02-27      100      False
# 2022-03-06       47      False
# 2022-03-13       33      False
# 2022-03-20       24      False
# 2022-03-27       17      False
# 2022-04-03       16      False
# 2022-04-10       14      False
# 2022-04-17       14      False
# 2022-04-24       12       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Numerai'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Numerai', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Numerai  isPartial
# date
# 2022-02-20        7      False
# 2022-02-27        2      False
# 2022-03-06        7      False
# 2022-03-13        8      False
# 2022-03-20       11      False
# 2022-03-27       16      False
# 2022-04-03       11      False
# 2022-04-10       11      False
# 2022-04-17        3      False
# 2022-04-24        9       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Gitcoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-100:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Gitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()
plt.xticks(rotation=45)

# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Gitcoin  isPartial
# date
# 2022-02-20        9      False
# 2022-02-27        8      False
# 2022-03-06        9      False
# 2022-03-13       14      False
# 2022-03-20       13      False
# 2022-03-27        5      False
# 2022-04-03        9      False
# 2022-04-10        7      False
# 2022-04-17        5      False
# 2022-04-24        0       True

# %%
#@title CeFi
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coinbase','FTX','Binance','Kraken'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Coinbase', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'FTX', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Kraken', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Binance', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coinbase  FTX  Binance  Kraken  isPartial
# date
# 2022-02-20         2    0        4       1      False
# 2022-02-27         2    0        4       1      False
# 2022-03-06         2    0        4       1      False
# 2022-03-13         2    0        4       1      False
# 2022-03-20         2    0        4       1      False
# 2022-03-27         2    0        4       1      False
# 2022-04-03         2    0        4       1      False
# 2022-04-10         2    0        4       1      False
# 2022-04-17         2    0        4       1      False
# 2022-04-24         1    0        3       1       True

# %%
#@title CNBC versus Crypto
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coindesk','Cryptotelegraph','CNBC','Coinmarketcap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Coindesk', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Cryptotelegraph', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'CNBC', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coinmarketcap', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coindesk  Cryptotelegraph  CNBC  Coinmarketcap  isPartial
# date
# 2022-02-20         1                0    40             46      False
# 2022-02-27         1                0    40             43      False
# 2022-03-06         1                0    40             42      False
# 2022-03-13         1                0    34             41      False
# 2022-03-20         1                0    33             53      False
# 2022-03-27         1                0    30             58      False
# 2022-04-03         1                0    29             50      False
# 2022-04-10         1                0    26             47      False
# 2022-04-17         1                0    29             40      False
# 2022-04-24         1                0    11             33       True

# %%
#@title CNBC versus Crypto
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Ukraine','Inflation','Super Bowl'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Ukraine', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Inflation', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Super Bowl', 'y1', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )


#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Ukraine  Inflation  Super Bowl  isPartial
# date
# 2022-02-20      100          1           1      False
# 2022-02-27      100          1           1      False
# 2022-03-06       47          1           1      False
# 2022-03-13       33          1           1      False
# 2022-03-20       24          1           0      False
# 2022-03-27       17          1           0      False
# 2022-04-03       16          1           0      False
# 2022-04-10       14          1           0      False
# 2022-04-17       14          1           0      False
# 2022-04-24       12          1           0       True

# %%
#@title  Computer science trends
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Linux','Windows','Mac'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Linux', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Windows', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Mac', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Linux  Windows  Mac  isPartial
# date
# 2022-02-20      7       39   28      False
# 2022-02-27      8       38   28      False
# 2022-03-06      8       40   30      False
# 2022-03-13      8       40   30      False
# 2022-03-20      8       39   28      False
# 2022-03-27      8       37   27      False
# 2022-04-03      8       37   26      False
# 2022-04-10      7       37   27      False
# 2022-04-17      7       37   27      False
# 2022-04-24      4       31   27       True

# %%
#@title Crypto Websites versus CNBC
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coingecko','CNBC','Coinmarketcap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df#[-50:]

print(interest_over_time_df.tail(10))

# multiple line plot
#plt.plot( 'Messari', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coingecko', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'CNBC', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coinmarketcap', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

# title
plt.title('Google Trends', loc='center',pad=10)

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()



# title
plt.title('Google Trends', loc='center',pad=10)



interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coingecko  CNBC  Coinmarketcap  isPartial
# date
# 2022-02-20         15    40             46      False
# 2022-02-27         14    40             43      False
# 2022-03-06         13    40             42      False
# 2022-03-13         12    34             41      False
# 2022-03-20         14    33             53      False
# 2022-03-27         16    30             58      False
# 2022-04-03         14    29             50      False
# 2022-04-10         12    26             47      False
# 2022-04-17         12    29             40      False
# 2022-04-24         10    11             33       True

# %%
#@title Gaming
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Xbox','PlayStation','Oculus'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Xbox', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PlayStation', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Oculus', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Xbox  PlayStation  Oculus  isPartial
# date
# 2022-02-20    32           12       6      False
# 2022-02-27    29           12       6      False
# 2022-03-06    29           12       6      False
# 2022-03-13    30           11       5      False
# 2022-03-20    30           12       5      False
# 2022-03-27    28           13       5      False
# 2022-04-03    30           11       5      False
# 2022-04-10    30           11       5      False
# 2022-04-17    29           10       5      False
# 2022-04-24    32           10       6       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Solidity','Cardano'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Solidity', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cardano', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Solidity  Cardano  isPartial
# date
# 2022-02-20         3       20      False
# 2022-02-27         2       16      False
# 2022-03-06         2       15      False
# 2022-03-13         2       14      False
# 2022-03-20         3       24      False
# 2022-03-27         2       21      False
# 2022-04-03         3       16      False
# 2022-04-10         3       15      False
# 2022-04-17         3       14      False
# 2022-04-24         2       14       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['modular blockchain'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'modular blockchain', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cardano', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             modular blockchain  isPartial
# date
# 2022-02-20                   0      False
# 2022-02-27                   0      False
# 2022-03-06                  49      False
# 2022-03-13                   0      False
# 2022-03-20                  25      False
# 2022-03-27                  46      False
# 2022-04-03                  43      False
# 2022-04-10                  73      False
# 2022-04-17                  70      False
# 2022-04-24                   0       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title
from pytrends.request import TrendReq
# Import necessary packages
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import pandas as pd
#import earthpy as et

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polygon MATIC','Arbitrum', 'Solana', 'Avalanche crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-52:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot
plt.plot( 'Polygon MATIC', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Arbitrum', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Solana', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Avalanche crypto', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)



interest_over_time_df.to_csv('layer_2.csv', encoding='utf-8')
# Out:
#             Polygon MATIC  Arbitrum  Solana  Avalanche crypto  isPartial
# date
# 2022-03-27              2         1      40                 1      False
# 2022-04-03              1         1      35                 1      False
# 2022-04-10              1         1      31                 1      False
# 2022-04-17              2         1      30                 1      False
# 2022-04-24              1         0      29                 1       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Litentry', 'Kilt Protocol'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Litentry', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Kilt Protocol', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
plt.xticks(rotation=45)



interest_over_time_df.to_csv('identity_protocol.csv', encoding='utf-8')
# Out:
#             Litentry  Kilt Protocol  isPartial
# date
# 2022-02-20         2              2      False
# 2022-02-27         2              2      False
# 2022-03-06         2              0      False
# 2022-03-13         4              1      False
# 2022-03-20         3              2      False
# 2022-03-27         3              3      False
# 2022-04-03         4              1      False
# 2022-04-10         4              2      False
# 2022-04-17         4              2      False
# 2022-04-24         0              3       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Uniswap', 'SushiSwap','PancakeSwap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Uniswap', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'SushiSwap', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PancakeSwap', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('AMM.csv', encoding='utf-8')
# Out:
#             Uniswap  SushiSwap  PancakeSwap  isPartial
# date
# 2022-02-20       10          2           18      False
# 2022-02-27       10          2           15      False
# 2022-03-06        9          1           15      False
# 2022-03-13       11          2           15      False
# 2022-03-20       11          2           17      False
# 2022-03-27       11          2           17      False
# 2022-04-03       10          2           15      False
# 2022-04-10        9          1           13      False
# 2022-04-17        9          2           15      False
# 2022-04-24        8          1           16       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Rarible', 'Superare','Nifty Gateway','OpenSea'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Rarible', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Superare', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Nifty Gateway', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'OpenSea', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('NFT_Markets.csv', encoding='utf-8')
# Out:
#             Rarible  Superare  Nifty Gateway  OpenSea  isPartial
# date
# 2022-02-20        2         1              0       52      False
# 2022-02-27        2         1              0       36      False
# 2022-03-06        2         1              0       29      False
# 2022-03-13        1         1              0       31      False
# 2022-03-20        1         2              1       30      False
# 2022-03-27        1         1              1       33      False
# 2022-04-03        1         1              1       33      False
# 2022-04-10        2         1              0       32      False
# 2022-04-17        1         1              0       31      False
# 2022-04-24        1         1              0       35       True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Axie Infinity', 'Superare','Nifty Gateway','OpenSea'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Axie Infinity', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Superare', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Nifty Gateway', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'OpenSea', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('swap_protocol.csv', encoding='utf-8')
# Out:
#             Axie Infinity  Superare  Nifty Gateway  OpenSea  isPartial
# date
# 2022-02-20             12         1              0       52      False
# 2022-02-27             11         1              0       36      False
# 2022-03-06             15         1              0       29      False
# 2022-03-13              8         1              0       31      False
# 2022-03-20             10         2              1       30      False
# 2022-03-27             13         1              1       33      False
# 2022-04-03             12         1              1       33      False
# 2022-04-10              9         1              0       32      False
# 2022-04-17              8         1              0       31      False
# 2022-04-24              6         1              0       35       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Axie Infinity','Pokémon'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Axie Infinity', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Pokémon', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('swap_protocol.csv', encoding='utf-8')
# Out:
#             Axie Infinity  Pokémon  isPartial
# date
# 2022-03-27             12       57      False
# 2022-04-03             12       59      False
# 2022-04-10              9       61      False
# 2022-04-17              8       58      False
# 2022-04-24              6       61       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Index Coop','Indexed','BasketDAO','PieDAO','PowerPool'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Index Coop', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Indexed', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'BasketDAO', 'y3', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PieDAO', 'y4', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'PowerPool', 'y5', data=df2, color='yellow', linewidth=3)

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('index.csv', encoding='utf-8')
# Out:
#             Index Coop  Indexed  BasketDAO  PieDAO  PowerPool  isPartial
# date
# 2022-03-27           2       88          0       0          0      False
# 2022-04-03           1       87          0       0          0      False
# 2022-04-10           2       77          0       0          0      False
# 2022-04-17           2       73          0       0          1      False
# 2022-04-24           2       48          0       0          0       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DigitalBits'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'DigitalBits', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv(r'C:\Users\charl\Google Drive\2021\investing_programs\AWS Serverless Application\Google_trends\output\swap_protocol.csv', encoding='utf-8')
# Out:
#             DigitalBits  isPartial
# date
# 2022-03-27            6      False
# 2022-04-03            5      False
# 2022-04-10            9      False
# 2022-04-17            7      False
# 2022-04-24            0       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Splinterlands','Axie Infinity'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Splinterlands', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Axie Infinity', 'y2', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Axie Infinity_protocol.csv', encoding='utf-8')
# Out:
#             Splinterlands  Axie Infinity  isPartial
# date
# 2022-03-27              1             16      False
# 2022-04-03              1             15      False
# 2022-04-10              1             11      False
# 2022-04-17              1             10      False
# 2022-04-24              1              7       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Rally RLY'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Rally RLY', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             Rally RLY  isPartial
# date
# 2022-03-27          6      False
# 2022-04-03          6      False
# 2022-04-10         13      False
# 2022-04-17          6      False
# 2022-04-24          0       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['MetaFactory'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'MetaFactory', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             MetaFactory  isPartial
# date
# 2022-03-27           58      False
# 2022-04-03           36      False
# 2022-04-10            0      False
# 2022-04-17           77      False
# 2022-04-24            0       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Audius'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Audius', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             Audius  isPartial
# date
# 2022-03-27      12      False
# 2022-04-03      26      False
# 2022-04-10      16      False
# 2022-04-17      21      False
# 2022-04-24      16       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Ethereum','Solana','Bitcoin', 'Axie Infinity'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Ethereum', 'y1', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Bitcoin', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Axie Infinity', 'y4', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Ethereum  Solana  Bitcoin  Axie Infinity  isPartial
# date
# 2022-03-27         6       1       22              1      False
# 2022-04-03         5       1       19              1      False
# 2022-04-10         4       1       20              0      False
# 2022-04-17         4       1       17              0      False
# 2022-04-24         3       1       15              0       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bearish','Bullish'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df
print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Bearish', 'y1', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Bullish', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )



plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Bearish  Bullish  isPartial
# date
# 2022-03-27       31       61      False
# 2022-04-03       33       60      False
# 2022-04-10       28       51      False
# 2022-04-17       30       57      False
# 2022-04-24       26       49       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['dotmoovs'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'dotmoovs', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('dotmoovs_Dataset.csv', encoding='utf-8')
# Out:
#             dotmoovs  isPartial
# date
# 2022-03-27        33      False
# 2022-04-03        26      False
# 2022-04-10        10      False
# 2022-04-17        33      False
# 2022-04-24       100       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Crypto','Stocks','Bonds', 'ETF'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Crypto', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Stocks', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Bonds', 'y4', data=df2, color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'ETF', 'y1', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Crypto_stocks_Dataset.csv', encoding='utf-8')
# Out:
#             Crypto  Stocks  Bonds  ETF  isPartial
# date
# 2022-03-27      41      20     11   13      False
# 2022-04-03      35      22     11   13      False
# 2022-04-10      33      20     12   11      False
# 2022-04-17      31      20     12   12      False
# 2022-04-24      25      13      9    8       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bankless'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Bankless', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Bankless_Dataset.csv', encoding='utf-8')
# Out:
#             Bankless  isPartial
# date
# 2022-03-27        76      False
# 2022-04-03        51      False
# 2022-04-10        44      False
# 2022-04-17        42      False
# 2022-04-24        21       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Yield Guild Games'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Yield Guild Games', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Bankless_Dataset.csv', encoding='utf-8')
# Out:
#             Yield Guild Games  isPartial
# date
# 2022-03-27                 10      False
# 2022-04-03                 15      False
# 2022-04-10                 17      False
# 2022-04-17                 10      False
# 2022-04-24                  0       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DeFi'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'DeFi', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             DeFi  isPartial
# date
# 2022-03-27    50      False
# 2022-04-03    47      False
# 2022-04-10    45      False
# 2022-04-17    45      False
# 2022-04-24    45       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Splinterlands'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Splinterlands', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Splinterlands  isPartial
# date
# 2022-03-27             15      False
# 2022-04-03             14      False
# 2022-04-10             16      False
# 2022-04-17             13      False
# 2022-04-24             15       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Loot','NFT'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Loot', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

plt.plot( 'NFT', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Loot  NFT  isPartial
# date
# 2022-03-27     4   37      False
# 2022-04-03     4   37      False
# 2022-04-10     4   39      False
# 2022-04-17     4   36      False
# 2022-04-24     4   28       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Android','iOS'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Android', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

plt.plot( 'iOS', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Android  iOS  isPartial
# date
# 2022-03-27       48   12      False
# 2022-04-03       51   12      False
# 2022-04-10       52   12      False
# 2022-04-17       47   12      False
# 2022-04-24       51   10       True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['$MATIC'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('$MATIC', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )



#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             $MATIC  isPartial
# date
# 2022-03-27       0      False
# 2022-04-03      10      False
# 2022-04-10       0      False
# 2022-04-17      16      False
# 2022-04-24       0       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DeFi','NFT','Ethereum'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('DeFi', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('NFT', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Ethereum', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             DeFi  NFT  Ethereum  isPartial
# date
# 2022-03-27     4   37        27      False
# 2022-04-03     4   37        22      False
# 2022-04-10     4   39        20      False
# 2022-04-17     3   36        18      False
# 2022-04-24     3   28        14       True

# %% [markdown]
# #Multichain World

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Binance','Solana','Ethereum','Fantom','Polygon MATIC'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Binance', 'y2', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Ethereum', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Fantom', 'y4', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Binance  Solana  Ethereum  Fantom  Polygon MATIC  isPartial
# date
# 2022-03-27        4       1         4       0              0      False
# 2022-04-03        4       1         4       0              0      False
# 2022-04-10        4       1         3       0              0      False
# 2022-04-17        4       1         3       0              0      False
# 2022-04-24        3       1         2       0              0       True
# Text(0.5, 1.0, 'Google Trends')

# %% [markdown]
# Facebook in multiyear decline

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Facebook','Twitter','Roblox','Tik Tok','Instagram'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Facebook', 'y2', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Twitter', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Roblox', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Tik Tok', 'y4', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Facebook  Twitter  Roblox  Tik Tok  Instagram  isPartial
# date
# 2022-03-27        27        9       3        1         13      False
# 2022-04-03        27        9       3        1         13      False
# 2022-04-10        27        9       3        1         13      False
# 2022-04-17        27        9       3        1         13      False
# 2022-04-24        27        9       4        1         15       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polkadot','Solana','Cardano','Fantom','Polygon MATIC'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Polkadot', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Cardano', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Fantom', 'y4', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Polkadot  Solana  Cardano  Fantom  Polygon MATIC  isPartial
# date
# 2022-03-27         4      24       21       5              1      False
# 2022-04-03         4      21       16       4              1      False
# 2022-04-10         4      18       15       4              1      False
# 2022-04-17         4      18       14       4              1      False
# 2022-04-24         4      18       14       4              1       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Somnium Space','Decentraland','The Sandbox'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Somnium Space', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Decentraland', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('The Sandbox', 'y1', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Somnium Space  Decentraland  The Sandbox  isPartial
# date
# 2022-03-27              0            21           18      False
# 2022-04-03              0            18           15      False
# 2022-04-10              1            16           12      False
# 2022-04-17              1            16           12      False
# 2022-04-24              0            13           11       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Sexism','Racism','Capitalism','Communism'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Sexism', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Racism', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Capitalism', 'y1', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Communism', 'y1', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Sexism  Racism  Capitalism  Communism  isPartial
# date
# 2022-03-27       1       7           3          4      False
# 2022-04-03       1       7           4          4      False
# 2022-04-10       1       7           3          4      False
# 2022-04-17       1       6           3          4      False
# 2022-04-24       1       7           3          3       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Capitalism','Communism'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot



plt.plot('Capitalism', 'y1', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('
plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Short USD  isPartial
# date
# 2022-03-27         41      False
# 2022-04-03         30      False
# 2022-04-10         34      False
# 2022-04-17         39      False
# 2022-04-24         31       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Gold'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Gold', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Gold  isPartial
# date
# 2022-03-27    69      False
# 2022-04-03    70      False
# 2022-04-10    73      False
# 2022-04-17    68      False
# 2022-04-24    72       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Commodities'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Commodities', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Commodities  isPartial
# date
# 2022-03-27           72      False
# 2022-04-03           72      False
# 2022-04-10           63      False
# 2022-04-17           65      False
# 2022-04-24           43       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Wheat'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Wheat', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Wheat  isPartial
# date
# 2022-03-27     72      False
# 2022-04-03     76      False
# 2022-04-10     76      False
# 2022-04-17     70      False
# 2022-04-24     63       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Gold'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Gold', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Gold  isPartial
# date
# 2022-03-27    69      False
# 2022-04-03    70      False
# 2022-04-10    73      False
# 2022-04-17    68      False
# 2022-04-24    72       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Silver'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Silver', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Silver  isPartial
# date
# 2022-03-27      64      False
# 2022-04-03      64      False
# 2022-04-10      68      False
# 2022-04-17      64      False
# 2022-04-24      67       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Oil'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Oil', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Oil  isPartial
# date
# 2022-03-27   63      False
# 2022-04-03   62      False
# 2022-04-10   61      False
# 2022-04-17   57      False
# 2022-04-24   60       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['War'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('War', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             War  isPartial
# date
# 2022-03-27   23      False
# 2022-04-03   24      False
# 2022-04-10   23      False
# 2022-04-17   22      False
# 2022-04-24   23       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['IPhone'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('IPhone', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()

*
# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             IPhone  isPartial
# date
# 2022-03-27      38      False
# 2022-04-03      37      False
# 2022-04-10      39      False
# 2022-04-17      39      False
# 2022-04-24      41       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['IPad'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('IPad', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             IPad  isPartial
# date
# 2022-03-27    64      False
# 2022-04-03    63      False
# 2022-04-10    64      False
# 2022-04-17    67      False
# 2022-04-24    69       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['MacBook'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('MacBook', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             MacBook  isPartial
# date
# 2022-03-27       60      False
# 2022-04-03       61      False
# 2022-04-10       59      False
# 2022-04-17       58      False
# 2022-04-24       46       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Apple'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Apple', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Apple  isPartial
# date
# 2022-03-27     32      False
# 2022-04-03     32      False
# 2022-04-10     33      False
# 2022-04-17     32      False
# 2022-04-24     35       True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Apple Cloud'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Apple Cloud', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )


 
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Apple Cloud  isPartial
# date
# 2022-03-27           67      False
# 2022-04-03           60      False
# 2022-04-10           64      False
# 2022-04-17           65      False
# 2022-04-24           66       True
# Text(0.5, 1.0, 'Google Trends')
