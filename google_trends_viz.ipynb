# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesdery/google-trends/blob/master/google_trends_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motivation
#
# This workbook scales the tracking of various Google Trends searches that I am personally interested in.
#
#
#
# ---

# %% [markdown]
# # Setup

# %%
#@title Install Dependencies
# !pip install pytrends
# !pwd

import seaborn as sns
# Out:
# Collecting pytrends
#   Downloading pytrends-4.7.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pytrends) (4.2.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytrends) (2.23.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from pytrends) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (2021.5.30)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.7.3
# /content

# %% [markdown]
# #Results
#  ---

# %% [markdown]
# #Memo
# *October 2021*
# * Crypto took over as most popular "asset class" on Google searches, beating stocks
# *  Although very nascent, crypto dominance can also be observed with the major crypto websites far exceeding CNBC
# * Bitcoin, still the most popular amongst the crypto space
# * Ethereum, comes in second
# * This cycle, NFT becomes the 1st use case beating the public's interest beyond the base layer Ethereum or DeFi
# * In other words, the public begins to engage with this technology i.e. collecting, gaming, building communities
# * Some research favourites, dominating their respective niche: Solana, Axie Infinity, OpenSea

# %%
#@title Crypto + Meme 

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto','Dogecoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Dogecoin', 'y4', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('giants.csv', encoding='utf-8')
# Out:
#             Bitcoin  Ethereum  Crypto  Dogecoin isPartial
# date
# 2021-08-22       26         7      11         3     False
# 2021-08-29       23         8      11         3     False
# 2021-09-05       29         8      13         3     False
# 2021-09-12       22         6      10         2     False
# 2021-09-19       27         6      10         2     False
# 2021-09-26       22         6       9         2     False
# 2021-10-03       26         6      11         3     False
# 2021-10-10       29         7      11         3     False
# 2021-10-17       38         8      12         3     False
# 2021-10-24       28         8      14         4      True

# %%
#@title Bitcoin versus Ethereum

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Bitcoin', 'y1', data=df,linestyle='-', linewidth=1, marker='o', ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, color='blue',linestyle='-', linewidth=1, marker='o', ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()

plt.grid()
# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('giants.csv', encoding='utf-8')
# Out:
#             Bitcoin  Ethereum isPartial
# date
# 2021-08-22       26         7     False
# 2021-08-29       23         8     False
# 2021-09-05       29         8     False
# 2021-09-12       22         6     False
# 2021-09-19       27         6     False
# 2021-09-26       22         6     False
# 2021-10-03       26         6     False
# 2021-10-10       29         7     False
# 2021-10-17       38         8     False
# 2021-10-24       28         8      True

# %%
#@title Layer 1
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polkadot', 'Cardano', 'Ethereum', 'Solana'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Polkadot', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Cardano', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Solana', 'y4', data=df, marker='o', color='orange',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Stellar', 'y5', data=df, marker='o', color='red', linewidth=2)
plt.legend()
plt.xticks(rotation=45)
# title
plt.title('Google Trends', loc='center',pad=10)

#sns.lineplot(data=df, x="date", y="score")
plt.show()

interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Polkadot  Cardano  Ethereum  Solana isPartial
# date
# 2021-08-22         2       24        32       6     False
# 2021-08-29         2       20        39      15     False
# 2021-09-05         2       19        38      17     False
# 2021-09-12         2       17        28      13     False
# 2021-09-19         2       13        28       7     False
# 2021-09-26         1       10        26       6     False
# 2021-10-03         2        9        30       8     False
# 2021-10-10         3        9        33       7     False
# 2021-10-17         3       10        40       9     False
# 2021-10-24         2        8        35      11      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['AAVE'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'AAVE', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             AAVE isPartial
# date
# 2021-08-22    37     False
# 2021-08-29    35     False
# 2021-09-05    33     False
# 2021-09-12    35     False
# 2021-09-19    32     False
# 2021-09-26    34     False
# 2021-10-03    31     False
# 2021-10-10    37     False
# 2021-10-17    32     False
# 2021-10-24    39      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Numerai'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Numerai', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Numerai isPartial
# date
# 2021-08-22        4     False
# 2021-08-29        8     False
# 2021-09-05        9     False
# 2021-09-12       13     False
# 2021-09-19        4     False
# 2021-09-26        4     False
# 2021-10-03       21     False
# 2021-10-10        4     False
# 2021-10-17        8     False
# 2021-10-24        0      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Gitcoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-100:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Gitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()
plt.xticks(rotation=45)

# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Gitcoin isPartial
# date
# 2021-08-22       23     False
# 2021-08-29       15     False
# 2021-09-05       10     False
# 2021-09-12       23     False
# 2021-09-19       18     False
# 2021-09-26       11     False
# 2021-10-03       11     False
# 2021-10-10       20     False
# 2021-10-17       18     False
# 2021-10-24        6      True

# %%
#@title CeFi
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coinbase','FTX','Binance','Kraken'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Coinbase', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'FTX', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Kraken', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Binance', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coinbase  FTX  Binance  Kraken isPartial
# date
# 2021-08-22         2    0        6       1     False
# 2021-08-29         2    0        6       1     False
# 2021-09-05         3    1        6       1     False
# 2021-09-12         2    0        5       1     False
# 2021-09-19         2    0        5       1     False
# 2021-09-26         2    0        4       2     False
# 2021-10-03         3    0        6       1     False
# 2021-10-10         3    0        6       3     False
# 2021-10-17         3    0        6       2     False
# 2021-10-24         4    1        7       3      True

# %%
#@title CNBC versus Crypto
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coindesk','Cryptotelegraph','CNBC','Coinmarketcap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-150:]

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Coindesk', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Cryptotelegraph', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'CNBC', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coinmarketcap', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coindesk  Cryptotelegraph  CNBC  Coinmarketcap isPartial
# date
# 2021-08-22         2                0    27             53     False
# 2021-08-29         1                0    25             56     False
# 2021-09-05         1                0    24             62     False
# 2021-09-12         1                0    25             58     False
# 2021-09-19         1                0    30             50     False
# 2021-09-26         1                0    30             45     False
# 2021-10-03         1                0    31             60     False
# 2021-10-10         1                0    28             59     False
# 2021-10-17         2                0    28             62     False
# 2021-10-24         1                0    21             70      True

# %%
#@title Crypto Websites versus CNBC
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coingecko','CNBC','Coinmarketcap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))

# multiple line plot
#plt.plot( 'Messari', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coingecko', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'CNBC', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coinmarketcap', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

# title
plt.title('Google Trends', loc='center',pad=10)

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()



# title
plt.title('Google Trends', loc='center',pad=10)



interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coingecko  CNBC  Coinmarketcap isPartial
# date
# 2021-08-22         27    28             53     False
# 2021-08-29         30    26             57     False
# 2021-09-05         28    23             65     False
# 2021-09-12         24    27             54     False
# 2021-09-19         27    31             52     False
# 2021-09-26         21    30             47     False
# 2021-10-03         27    30             59     False
# 2021-10-10         26    28             61     False
# 2021-10-17         28    28             61     False
# 2021-10-24         31    24             70      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Solidity','Cardano'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Solidity', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cardano', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Solidity  Cardano isPartial
# date
# 2021-08-22         1       83     False
# 2021-08-29         2       70     False
# 2021-09-05         2       66     False
# 2021-09-12         2       60     False
# 2021-09-19         2       44     False
# 2021-09-26         2       34     False
# 2021-10-03         2       33     False
# 2021-10-10         2       33     False
# 2021-10-17         2       35     False
# 2021-10-24         2       28      True

# %%
#@title
from pytrends.request import TrendReq
# Import necessary packages
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import pandas as pd
#import earthpy as et

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polygon MATIC','Arbitrum', 'Solana', 'Avalanche crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-52:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot
plt.plot( 'Polygon MATIC', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Arbitrum', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Solana', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Avalanche crypto', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)



interest_over_time_df.to_csv('layer_2.csv', encoding='utf-8')
# Out:
#             Polygon MATIC  Arbitrum  Solana  Avalanche crypto isPartial
# date
# 2021-09-26              2         1      38                 1     False
# 2021-10-03              2         1      48                 1     False
# 2021-10-10              3         1      42                 1     False
# 2021-10-17              4         0      56                 1     False
# 2021-10-24              4         1      67                 1      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Litentry', 'Kilt Protocol'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Litentry', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Kilt Protocol', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
plt.xticks(rotation=45)



interest_over_time_df.to_csv('identity_protocol.csv', encoding='utf-8')
# Out:
#             Litentry  Kilt Protocol isPartial
# date
# 2021-08-22         5              2     False
# 2021-08-29         2              5     False
# 2021-09-05         5              7     False
# 2021-09-12         8              2     False
# 2021-09-19         3              0     False
# 2021-09-26         3              2     False
# 2021-10-03         7              0     False
# 2021-10-10         2              0     False
# 2021-10-17         7              0     False
# 2021-10-24         0              0      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Uniswap', 'SushiSwap','PancakeSwap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Uniswap', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'SushiSwap', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PancakeSwap', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('AMM.csv', encoding='utf-8')
# Out:
#             Uniswap  SushiSwap  PancakeSwap isPartial
# date
# 2021-08-22       17          3           30     False
# 2021-08-29       21          3           33     False
# 2021-09-05       19          3           25     False
# 2021-09-12       17          4           29     False
# 2021-09-19       14          3           33     False
# 2021-09-26       18          2           26     False
# 2021-10-03       20          2           31     False
# 2021-10-10       28          4           40     False
# 2021-10-17       28          4           41     False
# 2021-10-24       36          4           38      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Rarible', 'Superare','Nifty Gateway','OpenSea'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Rarible', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Superare', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Nifty Gateway', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'OpenSea', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('NFT_Markets.csv', encoding='utf-8')
# Out:
#             Rarible  Superare  Nifty Gateway  OpenSea isPartial
# date
# 2021-08-22        6         6              2       61     False
# 2021-08-29        8         7              2      100     False
# 2021-09-05        5         6              1       76     False
# 2021-09-12        5         6              2       63     False
# 2021-09-19        3         5              1       54     False
# 2021-09-26        3         6              2       57     False
# 2021-10-03        4         5              1       65     False
# 2021-10-10        4         5              2       66     False
# 2021-10-17        6         7              2       73     False
# 2021-10-24        5         4              1       70      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Axie Infinity', 'Superare','Nifty Gateway','OpenSea'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Axie Infinity', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Superare', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Nifty Gateway', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'OpenSea', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('swap_protocol.csv', encoding='utf-8')
# Out:
#             Axie Infinity  Superare  Nifty Gateway  OpenSea isPartial
# date
# 2021-08-22             67         2              1       23     False
# 2021-08-29             57         3              1       37     False
# 2021-09-05             43         2              0       28     False
# 2021-09-12             38         2              1       23     False
# 2021-09-19             39         2              1       20     False
# 2021-09-26             38         2              1       21     False
# 2021-10-03             47         2              1       24     False
# 2021-10-10             45         2              1       24     False
# 2021-10-17             50         2              1       27     False
# 2021-10-24             39         1              1       26      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Axie Infinity','Pokémon'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Axie Infinity', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Pokémon', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('swap_protocol.csv', encoding='utf-8')
# Out:
#             Axie Infinity  Pokémon isPartial
# date
# 2021-09-26             31       71     False
# 2021-10-03             38       70     False
# 2021-10-10             37       71     False
# 2021-10-17             41       76     False
# 2021-10-24             31       77      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Index Coop','Indexed','BasketDAO','PieDAO','PowerPool'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Index Coop', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Indexed', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'BasketDAO', 'y3', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PieDAO', 'y4', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'PowerPool', 'y5', data=df2, color='yellow', linewidth=3)

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('index.csv', encoding='utf-8')
# Out:
#             Index Coop  Indexed  BasketDAO  PieDAO  PowerPool isPartial
# date
# 2021-09-26           1       72          0       0          1     False
# 2021-10-03           2       55          0       0          1     False
# 2021-10-10           4       65          0       0          1     False
# 2021-10-17           1       77          0       1          0     False
# 2021-10-24           0       65          0       0          0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DigitalBits'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'DigitalBits', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv(r'C:\Users\charl\Google Drive\2021\investing_programs\AWS Serverless Application\Google_trends\output\swap_protocol.csv', encoding='utf-8')
# Out:
#             DigitalBits isPartial
# date
# 2021-09-26            6     False
# 2021-10-03            8     False
# 2021-10-10            4     False
# 2021-10-17           10     False
# 2021-10-24           14      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Splinterlands','Axie Infinity'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Splinterlands', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Axie Infinity', 'y2', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Axie Infinity_protocol.csv', encoding='utf-8')
# Out:
#             Splinterlands  Axie Infinity isPartial
# date
# 2021-09-26              3             38     False
# 2021-10-03              3             47     False
# 2021-10-10              4             45     False
# 2021-10-17              4             50     False
# 2021-10-24              4             39      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Rally RLY'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Rally RLY', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             Rally RLY isPartial
# date
# 2021-09-26         42     False
# 2021-10-03          0     False
# 2021-10-10          0     False
# 2021-10-17          0     False
# 2021-10-24          0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['MetaFactory'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'MetaFactory', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             MetaFactory isPartial
# date
# 2021-09-26            0     False
# 2021-10-03            0     False
# 2021-10-10            0     False
# 2021-10-17            0     False
# 2021-10-24            0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Audius'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Audius', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             Audius isPartial
# date
# 2021-09-26      26     False
# 2021-10-03      17     False
# 2021-10-10      17     False
# 2021-10-17      15     False
# 2021-10-24      24      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Ethereum','Solana','Bitcoin', 'Axie Infinity'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Ethereum', 'y1', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Bitcoin', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Axie Infinity', 'y4', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Ethereum  Solana  Bitcoin  Axie Infinity isPartial
# date
# 2021-09-26         6       1       22              1     False
# 2021-10-03         6       2       26              2     False
# 2021-10-10         7       2       29              2     False
# 2021-10-17         8       2       38              2     False
# 2021-10-24         8       2       28              1      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['dotmoovs'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'dotmoovs', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('dotmoovs_Dataset.csv', encoding='utf-8')
# Out:
#             dotmoovs isPartial
# date
# 2021-09-26         0     False
# 2021-10-03        40     False
# 2021-10-10        28     False
# 2021-10-17        27     False
# 2021-10-24         0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Crypto','Stocks','Bonds', 'ETF'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Crypto', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Stocks', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Bonds', 'y4', data=df2, color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'ETF', 'y1', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Crypto_stocks_Dataset.csv', encoding='utf-8')
# Out:
#             Crypto  Stocks  Bonds  ETF isPartial
# date
# 2021-09-26      29      19     12   12     False
# 2021-10-03      38      21     11   12     False
# 2021-10-10      39      19     11   14     False
# 2021-10-17      42      20     10   20     False
# 2021-10-24      49      20     10   13      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bankless'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Bankless', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Bankless_Dataset.csv', encoding='utf-8')
# Out:
#             Bankless isPartial
# date
# 2021-09-26        50     False
# 2021-10-03       100     False
# 2021-10-10        39     False
# 2021-10-17        51     False
# 2021-10-24         0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Yield Guild Games'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Yield Guild Games', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Bankless_Dataset.csv', encoding='utf-8')
# Out:
#             Yield Guild Games isPartial
# date
# 2021-09-26                  7     False
# 2021-10-03                 22     False
# 2021-10-10                 31     False
# 2021-10-17                 30     False
# 2021-10-24                 52      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Splinterlands'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Splinterlands', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Splinterlands isPartial
# date
# 2021-09-26             51     False
# 2021-10-03             43     False
# 2021-10-10             62     False
# 2021-10-17             61     False
# 2021-10-24             65      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Loot','NFT'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Loot', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

plt.plot( 'NFT', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Loot  NFT isPartial
# date
# 2021-09-26    14   65     False
# 2021-10-03    14   78     False
# 2021-10-10    13   90     False
# 2021-10-17    13   93     False
# 2021-10-24    18   91      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DeFi','NFT','Ethereum'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('DeFi', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('NFT', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Ethereum', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             DeFi  NFT  Ethereum isPartial
# date
# 2021-09-26     5   20        26     False
# 2021-10-03     5   24        30     False
# 2021-10-10     5   28        33     False
# 2021-10-17     4   29        40     False
# 2021-10-24     4   28        35      True

# %% [markdown]
# #Multichain World

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Binance','Solana','Ethereum','Fantom','Polygon MATIC'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Binance', 'y2', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Ethereum', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Fantom', 'y4', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Binance  Solana  Ethereum  Fantom  Polygon MATIC isPartial
# date
# 2021-09-26        4       1         4       0              0     False
# 2021-10-03        6       1         5       0              0     False
# 2021-10-10        6       1         5       0              0     False
# 2021-10-17        6       2         7       0              0     False
# 2021-10-24        7       2         6       0              0      True
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polkadot','Solana','Cardano','Fantom','Polygon MATIC'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Polkadot', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Cardano', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Fantom', 'y4', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot('Polygon MATIC', 'y5', data=df2, color='purple',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
#             Polkadot  Solana  Cardano  Fantom  Polygon MATIC isPartial
# date
# 2021-09-26         4      22       34       4              1     False
# 2021-10-03         6      28       33       7              1     False
# 2021-10-10        11      25       33       6              2     False
# 2021-10-17         9      33       35       7              2     False
# 2021-10-24         7      39       28      10              2      True
# Text(0.5, 1.0, 'Google Trends')
