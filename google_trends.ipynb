# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesdery/google-trends/blob/master/google_trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Google Trends**

# %%
#@title Default title text
! pip install pytrends
# !pwd

import seaborn as sns
# Out:
# Requirement already satisfied: pytrends in /usr/local/lib/python3.7/dist-packages (4.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytrends) (2.23.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from pytrends) (1.1.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pytrends) (4.2.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pytrends) (1.24.3)
# /content

# %% [markdown]
# Start program

# %%
#@title Default title text

#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polkadot', 'Cardano', 'Ethereum', 'Solana'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Polkadot', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Cardano', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Solana', 'y4', data=df, marker='o', color='orange',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Stellar', 'y5', data=df, marker='o', color='red', linewidth=2)
plt.legend()
plt.xticks(rotation=45)
# title
plt.title('Google Trends', loc='center',pad=10)

#sns.lineplot(data=df, x="date", y="score")
plt.show()

interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Polkadot  Cardano  Ethereum  Solana isPartial
# date
# 2021-08-01         2        7        43       2     False
# 2021-08-08         2       15        43       3     False
# 2021-08-15         2       17        35       7     False
# 2021-08-22         2       25        32       6     False
# 2021-08-29         2       20        39      14     False
# 2021-09-05         2       19        38      18     False
# 2021-09-12         2       17        29      13     False
# 2021-09-19         2       13        28       8     False
# 2021-09-26         1       10        26       7     False
# 2021-10-03         2       10        31       8      True

# %%
#@title Default title text

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Bitcoin', 'y1', data=df,linestyle='-', linewidth=1, marker='o', ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, color='blue',linestyle='-', linewidth=1, marker='o', ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()

plt.grid()
# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('giants.csv', encoding='utf-8')
# Out:
#             Bitcoin  Ethereum isPartial
# date
# 2021-08-01       25         9     False
# 2021-08-08       29         9     False
# 2021-08-15       26         8     False
# 2021-08-22       26         7     False
# 2021-08-29       23         8     False
# 2021-09-05       29         8     False
# 2021-09-12       22         6     False
# 2021-09-19       27         6     False
# 2021-09-26       22         6     False
# 2021-10-03       27         7      True

# %%
#@title Macro

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto','Dogecoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Dogecoin', 'y4', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('giants.csv', encoding='utf-8')
# Out:
#             Bitcoin  Ethereum  Crypto  Dogecoin isPartial
# date
# 2021-08-01       25         9       8         3     False
# 2021-08-08       29         9      10         4     False
# 2021-08-15       26         8      10         5     False
# 2021-08-22       26         7      11         3     False
# 2021-08-29       23         8      12         3     False
# 2021-09-05       29         8      13         3     False
# 2021-09-12       22         6      10         2     False
# 2021-09-19       27         6      11         2     False
# 2021-09-26       22         6       9         2     False
# 2021-10-03       27         7      12         3      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['AAVE'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'AAVE', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             AAVE isPartial
# date
# 2021-08-01    41     False
# 2021-08-08    38     False
# 2021-08-15    37     False
# 2021-08-22    39     False
# 2021-08-29    32     False
# 2021-09-05    35     False
# 2021-09-12    35     False
# 2021-09-19    34     False
# 2021-09-26    33     False
# 2021-10-03    33      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Numerai'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Numerai', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Numerai isPartial
# date
# 2021-08-01        9     False
# 2021-08-08        5     False
# 2021-08-15       14     False
# 2021-08-22       19     False
# 2021-08-29        0     False
# 2021-09-05       19     False
# 2021-09-12        5     False
# 2021-09-19        5     False
# 2021-09-26        9     False
# 2021-10-03        5      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Gitcoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-100:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Gitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()
plt.xticks(rotation=45)

# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Gitcoin isPartial
# date
# 2021-08-01        8     False
# 2021-08-08        3     False
# 2021-08-15       11     False
# 2021-08-22       14     False
# 2021-08-29       17     False
# 2021-09-05       14     False
# 2021-09-12       15     False
# 2021-09-19       10     False
# 2021-09-26        8     False
# 2021-10-03       11      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coinbase','FTX','Binance','Kraken'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Coinbase', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'FTX', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Kraken', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Binance', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coinbase  FTX  Binance  Kraken isPartial
# date
# 2021-08-01         2    0        4       1     False
# 2021-08-08         3    0        5       1     False
# 2021-08-15         2    0        5       1     False
# 2021-08-22         2    0        5       1     False
# 2021-08-29         2    0        6       1     False
# 2021-09-05         3    1        6       1     False
# 2021-09-12         2    0        5       1     False
# 2021-09-19         2    0        5       1     False
# 2021-09-26         2    0        4       2     False
# 2021-10-03         3    0        6       2      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Coindesk','Cryptotelegraph','CNBC','Coinmarketcap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df[-150:]

print(interest_over_time_df.tail(10))
# multiple line plot
plt.plot( 'Coindesk', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Cryptotelegraph', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'CNBC', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coinmarketcap', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)

plt.xticks(rotation=45)


interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Coindesk  Cryptotelegraph  CNBC  Coinmarketcap isPartial
# date
# 2021-08-01         1                0    28             41     False
# 2021-08-08         2                0    26             50     False
# 2021-08-15         2                0    26             51     False
# 2021-08-22         2                0    26             52     False
# 2021-08-29         1                0    26             59     False
# 2021-09-05         1                0    23             64     False
# 2021-09-12         1                0    25             53     False
# 2021-09-19         1                0    31             52     False
# 2021-09-26         1                0    30             49     False
# 2021-10-03         1                0    31             59      True

# %%
#@title Default title text
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Messari','Coingecko','CNBC','Coinmarketcap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))

# multiple line plot
plt.plot( 'Messari', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coingecko', 'y2', data=df, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'CNBC', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Coinmarketcap', 'y4', data=df, color='orange',linestyle='-', linewidth=1,ms=1.5 )

# title
plt.title('Google Trends', loc='center',pad=10)

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()



# title
plt.title('Google Trends', loc='center',pad=10)



interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Messari  Coingecko  CNBC  Coinmarketcap isPartial
# date
# 2021-08-01        0         21    28             41     False
# 2021-08-08        0         23    26             50     False
# 2021-08-15        0         24    26             51     False
# 2021-08-22        0         26    26             52     False
# 2021-08-29        0         29    26             59     False
# 2021-09-05        0         27    23             64     False
# 2021-09-12        0         25    25             53     False
# 2021-09-19        0         26    31             52     False
# 2021-09-26        0         22    30             49     False
# 2021-10-03        0         27    31             59      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Solidity','Cardano'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Solidity', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'Cardano', 'y5', data=df, marker='x', color='red', linewidth=2)
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('layer_1.csv', encoding='utf-8')
# Out:
#             Solidity  Cardano isPartial
# date
# 2021-08-01         1       25     False
# 2021-08-08         1       54     False
# 2021-08-15         1       61     False
# 2021-08-22         2       89     False
# 2021-08-29         2       70     False
# 2021-09-05         2       69     False
# 2021-09-12         2       59     False
# 2021-09-19         2       45     False
# 2021-09-26         2       34     False
# 2021-10-03         2       35      True

# %%
#@title
from pytrends.request import TrendReq
# Import necessary packages
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import pandas as pd
#import earthpy as et

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()


# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Polygon MATIC','Arbitrum', 'Solana', 'Avalanche crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-52:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot
plt.plot( 'Polygon MATIC', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Arbitrum', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Solana', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Avalanche crypto', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)



interest_over_time_df.to_csv('layer_2.csv', encoding='utf-8')
# Out:
#             Polygon MATIC  Arbitrum  Solana  Avalanche crypto isPartial
# date
# 2021-09-05              3         1     100                 1     False
# 2021-09-12              2         5      73                 2     False
# 2021-09-19              2         2      43                 1     False
# 2021-09-26              2         1      38                 1     False
# 2021-10-03              2         1      43                 2      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Litentry', 'Kilt Protocol'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-20:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Litentry', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Kilt Protocol', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
plt.xticks(rotation=45)



interest_over_time_df.to_csv('identity_protocol.csv', encoding='utf-8')
# Out:
#             Litentry  Kilt Protocol isPartial
# date
# 2021-08-01         5              0     False
# 2021-08-08         3              0     False
# 2021-08-15         3              0     False
# 2021-08-22         7              0     False
# 2021-08-29         3              1     False
# 2021-09-05         7              6     False
# 2021-09-12         6              3     False
# 2021-09-19         3              0     False
# 2021-09-26         1              1     False
# 2021-10-03         5              0      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Uniswap', 'SushiSwap','PancakeSwap'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Uniswap', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'SushiSwap', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PancakeSwap', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('AMM.csv', encoding='utf-8')
# Out:
#             Uniswap  SushiSwap  PancakeSwap isPartial
# date
# 2021-08-01       17          2           21     False
# 2021-08-08       16          3           25     False
# 2021-08-15       17          3           26     False
# 2021-08-22       19          3           30     False
# 2021-08-29       19          4           32     False
# 2021-09-05       18          2           27     False
# 2021-09-12       15          4           31     False
# 2021-09-19       14          3           32     False
# 2021-09-26       16          3           24     False
# 2021-10-03       20          3           32      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Rarible', 'Superare','Nifty Gateway','OpenSea'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Rarible', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Superare', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Nifty Gateway', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'OpenSea', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('NFT_Markets.csv', encoding='utf-8')
# Out:
#             Rarible  Superare  Nifty Gateway  OpenSea isPartial
# date
# 2021-08-01        3         8              1       20     False
# 2021-08-08        4         5              2       35     False
# 2021-08-15        3         5              2       33     False
# 2021-08-22        7         6              3       64     False
# 2021-08-29        7         8              3      100     False
# 2021-09-05        5         7              2       78     False
# 2021-09-12        5         7              2       67     False
# 2021-09-19        5         6              1       55     False
# 2021-09-26        4         5              1       58     False
# 2021-10-03        4         6              2       70      True

# %%
#@title
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Axie Infinity', 'Superare','Nifty Gateway','OpenSea'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( 'Axie Infinity', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Superare', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Nifty Gateway', 'y3', data=df2,  color='orange',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'OpenSea', 'y4', data=df2,  color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('swap_protocol.csv', encoding='utf-8')
# Out:
#             Axie Infinity  Superare  Nifty Gateway  OpenSea isPartial
# date
# 2021-08-01             72         3              0        7     False
# 2021-08-08             70         2              1       12     False
# 2021-08-15             62         2              1       12     False
# 2021-08-22             68         2              1       23     False
# 2021-08-29             54         3              1       36     False
# 2021-09-05             45         2              1       28     False
# 2021-09-12             40         2              1       24     False
# 2021-09-19             39         2              1       20     False
# 2021-09-26             39         2              0       21     False
# 2021-10-03             46         2              1       25      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Axie Infinity','Pokémon'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Axie Infinity', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Pokémon', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('swap_protocol.csv', encoding='utf-8')
# Out:
#             Axie Infinity  Pokémon isPartial
# date
# 2021-09-05             35       68     False
# 2021-09-12             31       63     False
# 2021-09-19             31       75     False
# 2021-09-26             30       67     False
# 2021-10-03             36       67      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Index Coop','Indexed','BasketDAO','PieDAO','PowerPool'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Index Coop', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Indexed', 'y1', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'BasketDAO', 'y3', data=df2, color='black',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'PieDAO', 'y4', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
#plt.plot( 'PowerPool', 'y5', data=df2, color='yellow', linewidth=3)

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('index.csv', encoding='utf-8')
# Out:
#             Index Coop  Indexed  BasketDAO  PieDAO  PowerPool isPartial
# date
# 2021-09-05           1       65          0       0          0     False
# 2021-09-12           2       62          1       0          0     False
# 2021-09-19           1       75          0       0          1     False
# 2021-09-26           1       64          0       0          1     False
# 2021-10-03           2       52          0       0          0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DigitalBits'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'DigitalBits', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv(r'C:\Users\charl\Google Drive\2021\investing_programs\AWS Serverless Application\Google_trends\output\swap_protocol.csv', encoding='utf-8')
# Out:
#             DigitalBits isPartial
# date
# 2021-09-05            5     False
# 2021-09-12           11     False
# 2021-09-19            9     False
# 2021-09-26           13     False
# 2021-10-03            5      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Splinterlands','Axie Infinity'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Splinterlands', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Axie Infinity', 'y2', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Axie Infinity_protocol.csv', encoding='utf-8')
# Out:
#             Splinterlands  Axie Infinity isPartial
# date
# 2021-09-05              4             45     False
# 2021-09-12              4             40     False
# 2021-09-19              4             39     False
# 2021-09-26              3             39     False
# 2021-10-03              3             46      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Rally RLY'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Rally RLY', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             Rally RLY isPartial
# date
# 2021-09-05         21     False
# 2021-09-12          0     False
# 2021-09-19          0     False
# 2021-09-26          0     False
# 2021-10-03          0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['MetaFactory'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'MetaFactory', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             MetaFactory isPartial
# date
# 2021-09-05            0     False
# 2021-09-12            0     False
# 2021-09-19          100     False
# 2021-09-26           49     False
# 2021-10-03            0      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Audius'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Audius', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('MetaFactory_protocol.csv', encoding='utf-8')
# Out:
#             Audius isPartial
# date
# 2021-09-05      35     False
# 2021-09-12      35     False
# 2021-09-19      37     False
# 2021-09-26      17     False
# 2021-10-03      15      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['dotmoovs'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'dotmoovs', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('dotmoovs_Dataset.csv', encoding='utf-8')
# Out:
#             dotmoovs isPartial
# date
# 2021-09-05        25     False
# 2021-09-12        12     False
# 2021-09-19        24     False
# 2021-09-26         0     False
# 2021-10-03        14      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Crypto','Stocks','Bonds', 'ETF'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Crypto', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Stocks', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Bonds', 'y4', data=df2, color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'ETF', 'y1', data=df2, color='orange',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Crypto_stocks_Dataset.csv', encoding='utf-8')
# Out:
#             Crypto  Stocks  Bonds  ETF isPartial
# date
# 2021-09-05      44      17     10   11     False
# 2021-09-12      35      18     11   12     False
# 2021-09-19      36      19     10   11     False
# 2021-09-26      31      19     12   12     False
# 2021-10-03      40      21     12   12      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Bankless'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Bankless', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Bankless_Dataset.csv', encoding='utf-8')
# Out:
#             Bankless isPartial
# date
# 2021-09-05        80     False
# 2021-09-12        55     False
# 2021-09-19        89     False
# 2021-09-26        33     False
# 2021-10-03        64      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Yield Guild Games'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Yield Guild Games', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Bankless_Dataset.csv', encoding='utf-8')
# Out:
#             Yield Guild Games isPartial
# date
# 2021-09-05                 41     False
# 2021-09-12                 32     False
# 2021-09-19                 24     False
# 2021-09-26                 16     False
# 2021-10-03                 19      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Splinterlands'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Splinterlands', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Bankless DAO', 'y3', data=df2, color='red', linewidth=3)


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Splinterlands isPartial
# date
# 2021-09-05             68     False
# 2021-09-12             80     False
# 2021-09-19             58     False
# 2021-09-26             51     False
# 2021-10-03             52      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Loot','NFT'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-50:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot( 'Loot', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )

plt.plot( 'NFT', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )


plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Loot  NFT isPartial
# date
# 2021-09-05    14   78     False
# 2021-09-12    12   67     False
# 2021-09-19    13   64     False
# 2021-09-26    13   65     False
# 2021-10-03    13   75      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['DeFi','NFT','Ethereum'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('DeFi', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('NFT', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Ethereum', 'y1', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             DeFi  NFT  Ethereum isPartial
# date
# 2021-09-05     5   25        38     False
# 2021-09-12     5   21        29     False
# 2021-09-19     5   20        28     False
# 2021-09-26     4   21        26     False
# 2021-10-03     5   24        31      True

# %%
#@title

from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt



# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
pytrend.build_payload(kw_list=['Ethereum','Solana','Bitcoin'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df2=interest_over_time_df[-25:]

print(interest_over_time_df.tail())
# multiple line plot
# multiple line plot

plt.plot('Ethereum', 'y2', data=df2, color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Bitcoin', 'y2', data=df2, color='blue',linestyle='-', linewidth=1,ms=1.5 )
plt.plot('Solana', 'y3', data=df2, color='red',linestyle='-', linewidth=1,ms=1.5 )

plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)




interest_over_time_df.to_csv('Splinterlands_Dataset.csv', encoding='utf-8')
# Out:
#             Ethereum  Solana  Bitcoin isPartial
# date
# 2021-09-05         8       4       29     False
# 2021-09-12         6       3       22     False
# 2021-09-19         6       2       27     False
# 2021-09-26         6       1       22     False
# 2021-10-03         7       2       27      True
